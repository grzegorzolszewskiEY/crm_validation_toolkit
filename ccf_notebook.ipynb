# %%
from crm_validator.ccf.ccf_wrapper import CCFWrapper
import pandas as pd

# %%
CCF_DATA_FILEPATH = "C:\\Users\\mj115gl\\work_dir\\ccf_test_data.csv"
ccf_data = pd.read_csv(CCF_DATA_FILEPATH)

# %%
ccf_wrapper = CCFWrapper(ccf_data=ccf_data)

# %%
ccf_wrapper("print")
# Out:
# ...
# CCF ASSIGNMENT PROCESS (BACK-TESTING)
# ...
# 	Metrics
# 	-------
# 	m_ex/m_b	:0.51
#
# 	Report Values
# 	-------------
# 	m_ex	:102
# 	m_b	:200
# 	N	:98
# ...
#
# ...
# EAD COVERED FACILITIES
# ...
# 	Metrics
# 	-------
# 	m_ead/N	:0.46938775510204084
#
# 	Report Values
# 	-------------
# 	m_ead	:46
# 	N	:98
# ...
#
# ...
# CCF VALIDATION
# ...
# 	FACILITY GRADE - B
# 	------------------
# 		Metrics
# 		-------
# 		p-value	:1.8904037262922997e-10
# 		T-statistic	:-15.340373291499734
# 		N - m_ead	:15
#
# 		Report Values
# 		-------------
# 		N - m_ead	:15
# 		Estimated CCF average	:0.3766666666666667
# 		Realised CCF average	:0.6706666666666667
# 		Floor percentage	:0
# 		Floor used	:None
# 		Distribution of CCF	:{'min': 0.25, '05%': 0.271, '10%': 0.28400000000000003, '25%': 0.315, '50%': 0.39, '75%': 0.435, '90%': 0.46199999999999997, '95%': 0.476, 'max': 0.49}
# 		T statistic	:-15.340373291499734
# 		p-value	:1.8904037262922997e-10
# 		Variance	:0.07199733333333333
# 		Outliers	:15
# 	FACILITY GRADE - C
# ...
